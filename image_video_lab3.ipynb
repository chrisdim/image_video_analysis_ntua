# %% [markdown]
# # 3η ομαδική άσκηση στη Τεχνολογία και Ανάλυση Εικόνων και Βίντεο

# %% [markdown]
# # Image & Video Technology and Analysis
# ## Semester 8 - Spring 2021
# ## Laboratory Project 3
#     Christos Dimopoulos (031 17 037)
#     Drosos Lalias (031 17 881)

# %% [markdown]
# # 1. Θεωρητικό Μέρος

# %% [markdown]
# #### **1. Γιατί και πώς τα συνελικτικά δίκτυα άλλαξαν το τοπίο της παραδοσιακής επεξεργασίας εικόνας;**

# %% [markdown]
#  Τα CNNs άλλαξαν ριζικά τον τρόπο με τον οποίο επεξεργάζονται οι εικόνες από υπολογιστικά συστήματα. Παρατίθενται μερικοί λόγοι για του οποίους συνέβη κάτι τέτοιο:
#  - Σε αντίθεση με τις μέχρι πρότινος τεχνικές επεξεργασίας εικόνων και όρασης υπολογιστών, κατά τις οποίες η ανάπτυξη κάποιας μορφής μάθησης προϋπέθετε τον εντοπισμό και τη χρήση συγκεκριμένων χαρακτηριστικών σημείων ενδιαφέροντος (feature vectors)  και μια πιο αναλυτική πρόσεγγιση (detaied engineering), τα CNNS **τροφοδοτούνται απευθείας με ολόκληρες τις εικόνες** και όχι με μεμονωμένα χαρακτηριστικά τους. Με αυτόν τον τρόπο, επιτρέπουν τη δημιουργία δικτύων που αξιοποιούν μεγάλο όγκο πληροφορίας χαμηλού επιπέδου, χωρίς την ανάγκη δημιουργίας ενός ειδικού αλγορίθμου ανάλογα με το είδος του προβλήματος και των εικόνων.
#  - Τα συνελικτικά δίκτυα παρέχουν **καλή γενίκευση** σε προβλήματα κατηγοριοποίησης εικόνων, ελαχιστοποιώντας συγχρόνως το πλήθος των ελεύθερων παραμέτρων δίχως να περιορίζεται σημαντικά η υπολογιστική τους ισχύς (**large learning capacity**). Κάτι τέτοιο επιτυγχάνεται, τροποποιώντας την αρχιτεκτονική τους (depth, breadth, convolutional layers) ανάλογα με το εκάστοτε πρόβλημα. Συγκρινόμενα με τα απλά feedforward neural networks με επίπεδα παρομοίου μεγέθους, δηλαδή, τα CNNs **έχουν πολύ λιγότερερες συνδέσεις** - και κατ'επέκταση παραμέτρους - ως εκ τούτου εκπαιδεύονται πιο εύκολα και πιο γρήγορα, δίχως να επιβαρύνονται ως προς την απόδοση τους σε σημαντικό βαθμό.
#  - Παρόλο που η ανάκτηση εικόνων από το Διαδίκτυο είναι πλέον τετριμμένη υπόθεση, πολλές εξ αυτών δεν συνοδέυονται από κάποια ετικέτα που θα χρησίμευε σε προβλήματα κατηγοριοποίησης τους. Ως εκ τούτου, προϋπάρχουσες τεχνικές φαίνεται να μην μπορούν να αξιοποιήσουν στο έπακρον τα τεράστια datasets της σημερινής εποχής. Τη λύση δίνουν τα CNNs, τα οποία αφού εκπαιδευτούν **μπορούν να κάνουν ισχυρές και συχνά ορθές υποθέσεις σχετικά με τη φύση των εικόνων, διαχειρίζοντας με αυτόν τον τρόπο τεράστιο όγκο δεδομένων πολύ πιο εύκολα**. Αυτό συμβαίνει διότι, τα CNNs **μπορούν να αξιοποιήσουν τη σύγχρονη τεχνολογία των GPUs και τις τεχνικές γρήγορης υλοποίησης 2Δ συνέλιξης**, ώστε να εκπαιδευτούν γρήγορα πάνω σε πολύ μεγάλες βάσεις δεδομένων (πχ ImageNet, CIPHAR100) χωρίς να παρουσιάζουν αισθητά φαινόμενα overfitting.

# %% [markdown]
# #### **2. Περιγράψτε τη λειτουργία της Rectified Linear Unit (ReLU).**

# %% [markdown]
# Η Rectified Linear Unit (ReLU) είναι μια μη γραμμική συνάρτηση ενεργοποίησης, οριζόμενη ως το θετικό μέρος του ορίσματός της: <br> <br>
# $f(x) = max(0,x)$ <br> <br>
# ![image.png](data:image/png;base64,...)
# <br>
# όπου x είναι η είσοδος του νευρώνα. <br>
# Συγκριτικά με άλλες μη γραμμικότητες ενεργοποίησης (πχ tanh), η ReLU καταφέρνει την εκπαίδευση νευρωνικών δικτύων με τεχνικές gradient descent **πολή πιο γρήγορα** και κατ'επέκταση πολύ πιο αποδοτικά, αφού καθιστά εφικτή τη διαχείριση τεράστιων όγκων δεδομένων εκπαίδευσης (ImageNet dataset κλπ). Επιπλέον, επιτυγχάνει **αραιή ενεργοποίηση** νευρώνων (sparse activation) - περίπου μόνο το 50% των νευρώνων λαμβάνουν μη μηδενική τιμή εξόδου - με αποτέλεσμα να περιορίζονται φαινόμενα overfitting και vanishing gradient του δικτύου. Τέλος, συνιστά μια **εύκολα υλοποιήσιμη, scale invariant και αναλυτική συνάρτηση** που περιλαμβάνει μόνο συγκρίσεις, προσθέσεις και πολλαπλασιασμούς.

# %% [markdown]
# #### **Παρουσιάστε ένα συγκριτικό πίνακα με τα επίπεδα, το μέγεθος των φίλτρων, συνάρτηση ενεργοποίησης, πλήθος παραμέτρων και τεχνικές pooling και dropout που χρησιμοποιούν τα 3 διαφορετικά δίκτυα που παρουσιάζονται στα προαναφερθέντα άρθρα και σχολιάστε επαρκώς τις διαφορές τους. Ποια χαρακτηριστικά αυτών των τριών δικτύων είναι κατά τη γνώμη σας αυτά που συνέβαλαν στη σταδιακή αύξηση της ακρίβειας ταξινόμησης.**

# %% [markdown]
# | | LeNet | AlexNet | VGG |
# | :-: | :-: | :-: | :-: |
# |**Επίπεδα Δικτύου**| 7 layers | 8 layers <br>  | 16 layers |
# |**Μέγεθος Φίλτρων**| 5x5x3 kernel-sized filters | 11x11x3 & 5x5x3 & 3x3x3 kernel-sized filters | 3×3x3 kernel-sized filters |
# |**Συνάρτηση Ενεργοποίησης**| Sigmoid | ReLU | ReLU, Softmax |
# |**Πλήθος Παραμέτρων**| 3,246 | 62 million | 138 million |
# |**Τεχνικές Pooling**| average-pooling of size 2x2 with a stride of 2 | max-pooling of size 3×3 with a stride of 2 | max-pooling of size 2 × 2 with strides of 2 |
# |**Τεχνικές Dropout**| None | Yes (p = 50%) | None |

# %% [markdown]
# Συγκρίνοντας μεταξύ τους τα τρία συνελικτικά δίκτυα, οδηγούμαστε στις εξής παρατηρήσεις:
# - Το νευρωνικόυ δίκτυο **Lenet** είναι η πιο πρώιμη μορφή συνελικτικού δικτύου, καθώς όπως φαίνεται έχει τα λιγότερα επίπεδα και τις λιγότερες εκπαιδεύσιμες παραμέτρους. Επιπλέον, είναι το μόνο εκ των τριών δεν χρησιμοποιεί τα πλεονεκτήματα που παρέχει η μη-γραμμική συνάρτηση RELU, καθώς ως βασική συνάρτηση ενεργοποίησης έχει τη sigmoid, ενώ είναι το μόνο που χρησιμοποιεί τεχνική average-pooling και όχι max-pooling. Σημειώνεται, επίσης, ότι η αρχική λειτουργία του εν λόγω δικτύου προοριζόταν για πρόβλημα κατηγοριοποίησης εικόνων μόλις 10 κλάσεων (ψηφία 0-9), εξού και η απλούστερη αρχιτεκτονική του.
# - Το δίκτυο **AlexNet** χρησιμοποεί τα φίλτρα με τη μεγαλύτερη διάσταση ανάμεσα στα 3 CNNs, ενώ μάλιστα είναι το μόνο που κάνει χρήση τριών διαφορετικών διαστάσεων φίλτρων ανά επίπεδο (11x11, 5x5, 3x3). Το γεγονός αυτό οφείλεται στο ότι λαμβάνει ως είσοδο εικόνες μεγάλων διαστάσεων (224x224 pixels). Επιπλέον, είναι το πρώτο που αξιοποιεί τη μη γραμμικότητα της ReLU και το μοναδικό εκ των τριών που κάνει χρήση τεχνικών Dropout για την αντιμετώπιση φαινομένων overfitting.
# - Το δίκτυο **VGG** είναι το μεγαλύτερο σε βάθος δίκτυο ανάμεσα στα 3, καθώς διαθέτει πολλά επίπεδα και εκατοντάδες εκατομμύρια εκπαιδεύσιμων παραμέτρων. Ως αποτέλεσμα, όπως θα φανεί και στην πειραματική υλοποίηση του εργαστηρίου, είναι το πιο αργό κατά την εκπαίδευση, ενώ φαίνεται να λειτουργεί καλύτερα με Stochastic Gradient Descent Optimizers. Επιπλέον, είναι το μόνο δίκτυο που στο τελευταίο layer κάνει χρήση της συνάρτησης ενεργοποίησης Softmax.

# %% [markdown]
# Ένα βασικό χαρακτηριστικό των τριών παραπάνω δικτύων που συνέβαλε στη σταδιακή αύξηση της ακρίβειας ταξινόμησης είναι η χρήση **συναρτήσεων ενεργοποίησης**, καθώς μέσω αυτών μοντελοποιείται η **μη γραμμικότητα** του προβλήματος. Επιπλέον, η **πολυεπίπεδη αρχιτεκτονική** των δικτύων επιτρέπει την τροφοδότηση τους απευθείας με την εικόνα και τη σταδιακή 'αποσύνθεση' της για feature extraction και στη συνέχεια classification tasks. Ακόμα, **το πλήθος των παραμέτρων** διατηρείται όσο το δυνατόν ελάχιστο, ώστε η εκπαίδευση τους να γίνεται γρήγορα και αξιοποιώντας τεχνολογίες GPU. Τέλος, και οι τρεις αρχιτεκτονικές μπορούν εύκολα να **προσαρμοστούν** με την εισαγωγή και τροποποίηση επιπέδων καθώς και τεχνικών **pooling & dropout** που φάνηκαν ιδιαίτερα αποτελεσματικές στην αντιμετώπιση φαινομένων overfitting & vanishing gradient, οδηγώντας εν τέλει σε αυξημένα ποσοστά ευστοχίας.

# %% [markdown]
# **LeNet & AlexNet Architectures:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **VGG Architecture:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Πειραματικό Μέρος

# %% [markdown]
# ## Εισαγωγή και επισκόπηση του συνόλου δεδομένων

# %%
from __future__ import absolute_import, division, print_function, unicode_literals # legacy compatibility

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# helper functions

# select from from_list elements with index in index_list
def select_from_list(from_list, index_list):
    filtered_list= [from_list[i] for i in index_list]
    return(filtered_list)

# append in filtered_list the index of each element of unfilterd_list if it exists in in target_list
def get_ds_index(unfiliterd_list, target_list):
    index = 0
    filtered_list=[]
    for i_ in unfiliterd_list:
        if i_[0] in target_list:
            filtered_list.append(index)
        index += 1
    return(filtered_list)

# %%
# load the entire dataset
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

(x_train_all, y_train_all), (x_test_all, y_test_all) = tf.keras.datasets.cifar100.load_data(label_mode='fine')
# Out:
# ...
# 169009152/169001437 [==============================] - 2s 0us/step

# %%
print(x_train_all.shape)
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# Η κάθε ομάδα θα δουλέψει με διαφορετικό υποσύνολο του dataset.
# Στο επόμενο κελί, αντικαταστήστε την τιμή της μεταβλητής `team_seed` με τον αριθμό που αντιστοιχεί στην ομάδας σας.

# %%
# REPLACE WITH YOUR TEAM NUMBER
team_seed = 22

# %%
# select from CIFAR100 20 classes
cifar100_classes_url = "https://pastebin.com/raw/nzE1n98V"
classes_num = 20

# %% [markdown]
# Δημιουργούμε το μοναδικό dataset της ομάδας μας:

# %%
team_classes = pd.read_csv(cifar100_classes_url, sep=',', header=None)
CIFAR100_LABELS_LIST = pd.read_csv('https://pastebin.com/raw/qgDaNggt', sep=',', header=None).astype(str).values.tolist()[0]

our_index = team_classes.iloc[team_seed,:].values.tolist()
our_classes = select_from_list(CIFAR100_LABELS_LIST, our_index)
train_index = get_ds_index(y_train_all, our_index)
test_index = get_ds_index(y_test_all, our_index)

x_train_ds = np.asarray(select_from_list(x_train_all, train_index))
y_train_ds = np.asarray(select_from_list(y_train_all, train_index))
x_test_ds = np.asarray(select_from_list(x_test_all, test_index))
y_test_ds = np.asarray(select_from_list(y_test_all, test_index))

# %%
# print our classes
print(our_classes)
# Out:
# [' aquarium_fish', ' bee', ' bottle', ' cattle', ' couch', ' crab', ' crocodile', ' dinosaur', ' flatfish', ' forest', ' keyboard', ' leopard', ' orange', ' road', ' spider', ' telephone', ' television', ' tiger', ' trout', ' woman']

# %%
print(x_train_ds[1].shape)
# Out:
# (32, 32, 3)

# %%
# get (train) dataset dimensions
data_size, img_rows, img_cols, img_channels = x_train_ds.shape

# set validation set percentage (wrt the training set size)
validation_percentage = 0.15
val_size = round(validation_percentage * data_size)

# Reserve val_size samples for validation and normalize all values
x_val = x_train_ds[-val_size:]/255
y_val = y_train_ds[-val_size:]
x_train = x_train_ds[:-val_size]/255
y_train = y_train_ds[:-val_size]
x_test = x_test_ds/255
y_test = y_test_ds

# summarize loaded dataset
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Validation: X=%s, y=%s' % (x_val.shape, y_val.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))

# get class label from class index
def class_label_from_index(fine_category):
    return(CIFAR100_LABELS_LIST[fine_category.item(0)])

# plot first few images
plt.figure(figsize=(6, 6))
for i in range(9):
    # define subplot
    plt.subplot(330 + 1 + i).set_title(class_label_from_index(y_train[i]))
    # plot raw pixel data
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    #show the figure
plt.show()
# Out:
# Train: X=(8500, 32, 32, 3), y=(8500, 1)
# Validation: X=(1500, 32, 32, 3), y=(1500, 1)
# Test: X=(2000, 32, 32, 3), y=(2000, 1)

# %%
# Map Image Labels to [0, classes_num-1] = [0, 19]
def create_dictionary(label_ds):
    dictionary = {}
    i=0
    for label in label_ds:
        if label not in dictionary.keys():
          dictionary[label] = i
          i+=1
    return dictionary

def mapping(label_ds,dictionary): 
    return [dictionary[x] for x in label_ds]


# Create Label Dict
label_dict = create_dictionary(y_train.reshape(1,-1)[0])
# Apply mapping
y_train = mapping(y_train.reshape(1,-1)[0], label_dict)
y_test = mapping(y_test.reshape(1,-1)[0], label_dict)
y_val = mapping(y_val.reshape(1,-1)[0], label_dict)

y_train = np.array([[i] for i in y_train])
y_test = np.array([[i] for i in y_test])
y_val = np.array([[i] for i in y_val])

# %% [markdown]
# ## Διαχείριση μνήμης (TFRecord)
# Η φόρτωση δεδομένων με τον τρόπο που το κάναμε παραπάνω στο απλό παράδειγμα υλοποίησης είναι πολύ βολική αλλά δεν είναι αποτελεσματική ως προς τη διαχείριση της μνήμης. Συγκεκριμένα, με τον τρόπο αυτό, τα δεδομένα αποθηκεύονται απευθείας σε μεταβλητές, οι οποίες όλες μαζί καταλαμβάνουν τη RAM της CPU ή της GPU, κάτι που κάνει αδύνατη τη διαχείριση μεγάλων datasets ή τον μεταχηματισμό των δεδομένων όπως όταν κάνουμε αύξηση δεδομένων (data augmentation).
#
# Για να παρακαμφθεί αυτό το πρόβλημα, υπάρχει η δυνατότητα της σειριοποίησης των δεδομένων (serialization) και της αποθήκευσής τους σε αρχεία μεσαίου μεγέθους (κάποιων MB) τα οποία μπορούν να αναγνωστούν γραμμικά.
#
# Το φορμάτ TFRecord είναι ένα φορμάτ που επιτρέπει την αποθήκευση σειράς δυαδικών εγγραφών. Διαβάστε σχετικά για το [TFRecord and tf.Example](https://www.tensorflow.org/tutorials/load_data/tfrecord) και [tf.data: Build TensorFlow input pipelines](https://www.tensorflow.org/guide/data).
#
# Σημειώστε ότι με τη μέθοδο αυτή θα πρέπει να γίνει import η `tensorflow_datasets` και να χρησιμοποιήσουμε την `tfds.load` ώστε να αποθηκευθεί το σύνολο δεδομένων σε αρχεία tfrecord στο δίσκο (δείτε [εδώ](https://colab.research.google.com/github/tensorflow/datasets/blob/master/docs/overview.ipynb) ένα παράδειγμα). Φυσικά μπορούμε να μετατρέψουμε και τα πρωτογενή δεδομένα (raw data) του dataset όπως αρχεία jpg σε φορματ tfrecord όπως [εδώ](https://towardsdatascience.com/working-with-tfrecords-and-tf-train-example-36d111b3ff4d).

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import load_model
import datetime
# data augmentation
# !pip install h5py

# %%
(ds_train, ds_test), ds_info = tfds.load('cifar100', split=['train', 'test'], shuffle_files=True, as_supervised=True, with_info=True)
assert isinstance(ds_train, tf.data.Dataset)
assert isinstance(ds_test, tf.data.Dataset)
# Out:
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/cifar100/3.0.2.incomplete8205GA/cifar100-train.tfrecord
# ...
# Shuffling and writing examples to /root/tensorflow_datasets/cifar100/3.0.2.incomplete8205GA/cifar100-test.tfrecord
# ...
# Dataset cifar100 downloaded and prepared to /root/tensorflow_datasets/cifar100/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# ## Ερώτημα 1

# %%
# Useful Functions

# Function that plots learning curve of model history
def plot_accuracy(history):
    plt.figure(figsize=(8, 5))
    plt.title('Classification Accuracy Curve')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.plot(history.history['accuracy'], color='blue', label='train')
    plt.plot(history.history['val_accuracy'], color='red', label='val')
    plt.legend(loc='upper right')
    return plt
 
# Function that Evaluates Model on its Accuracy
def model_evaluation(model, eval_steps):
    print('\nTest set Evaluation metrics')
    loss, accuracy = model.evaluate(x_test, y_test, steps = eval_steps)
    print("Loss: {:.2f}".format(loss))
    print("Accuracy: {:.2f}".format(accuracy))

# %% [markdown]
# ---
# #### **Βήμα 1: Σχεδίαση, μεταγλώττιση και εκπαίδευση των μοντέλων**
#
#  1. Σχεδίαστε, μεταγλωττίστε και εκπαιδεύστε τα μοντέλα  **LeNet, AlexNet και  VGG**, καθώς και ένα δικό σας μοντέλο (ονομάστε το π.χ. **MyCNN**) χρησιμοποιώντας διαφορετικούς συνδυασμούς (τουλάχιστον 2 ανά μοντέλο) για [optimizer](https://keras.io/api/optimizers/), [loss](https://keras.io/api/losses/), batch size και epoch.  Για [metrics](https://keras.io/api/metrics/) να χρησιμοποιήσετε την ορθότητα (όπως στο Lab9.1).
# ---

# %% [markdown]
# ### **LeNet Model**
# CONV(32, 3), RELU, AVG_POOL(2), CONV(32,3), RELU, AVG_POOL(2), FC(512), RELU, FC(200),SOFTMAX<br>
#
# Σημειώνεται ότι ως συναρτήσεις ενεργοποίησης, επιλέγουμε να χρησιμοποιήσουμε τη ReLU και όχι τη Sigmoid, με την οποία ορίστηκε το Lenet στο Θεωρητικό Μέρος, καθώς η πρώτη αποδίδει πολύ καλύτερα σε τεχνικές gradient descent (SGD optimizer).

# %%
#CONV(32, 3), RELU, AVG_POOL(2), CONV(32,3), RELU, AVG_POOL(2), FC(512), RELU, FC(200),SOFTMAX
def LeNet_model(combination = 1):
  
    if combination == 1:
        optimizer = 'adam'
        loss = tf.keras.losses.sparse_categorical_crossentropy
    else:
        optimizer = 'sgd'
        loss = tf.keras.losses.sparse_categorical_crossentropy

    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='sigmoid', input_shape=(32, 32, 3)))
    model.add(layers.AveragePooling2D((2, 2)))
    model.add(layers.Conv2D(32, (3, 3), activation='sigmoid'))
    model.add(layers.AveragePooling2D((2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(120, activation='sigmoid'))
    model.add(layers.Dense(84, activation='sigmoid'))
    model.add(layers.Dense(classes_num, activation='softmax'))
    model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"])
    model.summary()
    return model

# %%
# 1st Combination of LeNet Model - Adam Optimizer, Cross Entropy Loss
LeNet1 = LeNet_model(combination=1)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_15 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# average_pooling2d_10 (Averag (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 13, 13, 32)        9248
# _________________________________________________________________
# average_pooling2d_11 (Averag (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 120)               138360
# _________________________________________________________________
# dense_19 (Dense)             (None, 84)                10164
# ...

# %%
model_history1 = LeNet1.fit(x_train, y_train, epochs=30, batch_size=64, validation_data=(x_val, y_val)) # 30 epochs
LeNet1.save('lenet1.h5')
# Out:
# Epoch 1/30
# 133/133 [==============================] - 1s 7ms/step - loss: 3.0127 - accuracy: 0.0444 - val_loss: 3.0021 - val_accuracy: 0.0467
# Epoch 2/30
# 133/133 [==============================] - 1s 4ms/step - loss: 2.9924 - accuracy: 0.0564 - val_loss: 2.9571 - val_accuracy: 0.0640
# Epoch 3/30
# 133/133 [==============================] - 1s 4ms/step - loss: 2.8731 - accuracy: 0.1349 - val_loss: 2.7932 - val_accuracy: 0.1773
# Epoch 4/30
# 133/133 [==============================] - 1s 4ms/step - loss: 2.7401 - accuracy: 0.1720 - val_loss: 2.6718 - val_accuracy: 0.2007
# Epoch 5/30
# 133/133 [==============================] - 1s 4ms/step - loss: 2.6073 - accuracy: 0.2131 - val_loss: 2.5099 - val_accuracy: 0.2527
# Epoch 6/30
# 133/133 [==============================] - 1s 4ms/step - loss: 2.5063 - accuracy: 0.2478 - val_loss: 2.4243 - val_accuracy: 0.2680
# Epoch 7/30
# ...

# %%
# 2nd Combination of LeNet Model - Stochastic Gradient Descent Optimizer, Cross Entropy Loss
LeNet2 = LeNet_model(combination=2)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_17 (Conv2D)           (None, 30, 30, 32)        896
# _________________________________________________________________
# average_pooling2d_12 (Averag (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 13, 13, 32)        9248
# _________________________________________________________________
# average_pooling2d_13 (Averag (None, 6, 6, 32)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_21 (Dense)             (None, 120)               138360
# _________________________________________________________________
# dense_22 (Dense)             (None, 84)                10164
# ...

# %%
model_history2 = LeNet2.fit(x_train, y_train, epochs=50, batch_size=256, validation_data=(x_val, y_val)) # 50 epochs
LeNet2.save('lenet2.h5')
# Out:
# Epoch 1/50
# 34/34 [==============================] - 1s 12ms/step - loss: 2.9960 - accuracy: 0.0522 - val_loss: 2.9975 - val_accuracy: 0.0373
# Epoch 2/50
# 34/34 [==============================] - 0s 9ms/step - loss: 2.9959 - accuracy: 0.0522 - val_loss: 2.9979 - val_accuracy: 0.0373
# Epoch 3/50
# 34/34 [==============================] - 0s 9ms/step - loss: 2.9959 - accuracy: 0.0485 - val_loss: 2.9980 - val_accuracy: 0.0373
# Epoch 4/50
# 34/34 [==============================] - 0s 10ms/step - loss: 2.9959 - accuracy: 0.0507 - val_loss: 2.9979 - val_accuracy: 0.0373
# Epoch 5/50
# 34/34 [==============================] - 0s 9ms/step - loss: 2.9959 - accuracy: 0.0522 - val_loss: 2.9977 - val_accuracy: 0.0373
# Epoch 6/50
# 34/34 [==============================] - 0s 9ms/step - loss: 2.9960 - accuracy: 0.0511 - val_loss: 2.9982 - val_accuracy: 0.0373
# Epoch 7/50
# ...

# %% [markdown]
# Παρατηρούμε ότι στην πρώτη περίπτωση, με τη χρήση του Adam optimizer, επιτυγχάνουμε καλύτερα αποτελέσματα, ενώ ο SGD optimizer αποτυγχάνει παταγωδώς, καθώς γίνεται χρήση της μη γραμμικής συνάρτησης sigmoid, η οποία δεν ενδείκνυται για τεχνικές gradient descent. Όπως θα φανεί παρακάτω, η ReLU φαίνεται να αποδίδει και με optimizers SGD.

# %% [markdown]
# ### **AlexNet Model**

# %%
def AlexNet_model(combination = 1):
  
    if combination == 1:
        optimizer = 'adam'
        loss = tf.keras.losses.sparse_categorical_crossentropy
    else:
        optimizer = 'sgd'
        loss = tf.keras.losses.sparse_categorical_crossentropy
  
    model = models.Sequential()
    model.add(layers.experimental.preprocessing.Resizing(224, 224, interpolation="bilinear", input_shape=x_train.shape[1:]))
    model.add(layers.Conv2D(96, 11, strides=4, padding='same'))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Lambda(tf.nn.local_response_normalization))
    model.add(layers.Activation('relu'))
    model.add(layers.MaxPooling2D(3, strides=2))
    model.add(layers.Conv2D(256, 5, strides=4, padding='same'))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Lambda(tf.nn.local_response_normalization))
    model.add(layers.Activation('relu'))
    model.add(layers.MaxPooling2D(3, strides=2))
    model.add(layers.Conv2D(384, 3, strides=4, padding='same'))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Activation('relu'))
    model.add(layers.Conv2D(384, 3, strides=4, padding='same'))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Activation('relu'))
    model.add(layers.Conv2D(256, 3, strides=4, padding='same'))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Activation('relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(classes_num, activation='softmax'))

    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

    model.summary()
    return model

# %%
# 1st Combination of AlexNet Model
AlexNet1 = AlexNet_model(combination=1)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# resizing_1 (Resizing)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 56, 56, 96)        34944
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 56, 56, 96)        384
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 56, 56, 96)        0
# _________________________________________________________________
# activation_5 (Activation)    (None, 56, 56, 96)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 7, 7, 256)         614656
# ...

# %%
model_history3 = AlexNet1.fit(x_train, y_train,  epochs=15, validation_data=(x_val, y_val)) # 15 epochs
AlexNet1.save('alexnet1.h5')
# Out:
# Epoch 1/15
# 266/266 [==============================] - 19s 69ms/step - loss: 2.5479 - accuracy: 0.2388 - val_loss: 2.1396 - val_accuracy: 0.3447
# Epoch 2/15
# 266/266 [==============================] - 18s 68ms/step - loss: 2.1500 - accuracy: 0.3609 - val_loss: 2.0313 - val_accuracy: 0.4067
# Epoch 3/15
# 266/266 [==============================] - 18s 68ms/step - loss: 1.9231 - accuracy: 0.4327 - val_loss: 1.8055 - val_accuracy: 0.4507
# Epoch 4/15
# 266/266 [==============================] - 18s 68ms/step - loss: 1.7345 - accuracy: 0.4822 - val_loss: 1.9766 - val_accuracy: 0.4173
# Epoch 5/15
# 266/266 [==============================] - 18s 68ms/step - loss: 1.5710 - accuracy: 0.5335 - val_loss: 1.6186 - val_accuracy: 0.5313
# Epoch 6/15
# 266/266 [==============================] - 18s 68ms/step - loss: 1.4398 - accuracy: 0.5738 - val_loss: 1.6524 - val_accuracy: 0.5200
# Epoch 7/15
# ...

# %%
# 2nd Combination of AlexNet Model
AlexNet2 = AlexNet_model(combination=2)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# resizing_4 (Resizing)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 56, 56, 96)        34944
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 56, 56, 96)        384
# _________________________________________________________________
# lambda_4 (Lambda)            (None, 56, 56, 96)        0
# _________________________________________________________________
# activation_10 (Activation)   (None, 56, 56, 96)        0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 7, 7, 256)         614656
# ...

# %%
model_history4 = AlexNet2.fit(x_train, y_train,  epochs=25, validation_data=(x_val, y_val)) # 25 epochs
AlexNet2.save('alexnet2.h5')
# Out:
# Epoch 1/25
# 266/266 [==============================] - 167s 626ms/step - loss: 2.8743 - accuracy: 0.1248 - val_loss: 2.4229 - val_accuracy: 0.2753
# Epoch 2/25
# 266/266 [==============================] - 177s 666ms/step - loss: 2.3321 - accuracy: 0.2968 - val_loss: 2.0545 - val_accuracy: 0.3847
# Epoch 3/25
# 266/266 [==============================] - 169s 636ms/step - loss: 2.0022 - accuracy: 0.3937 - val_loss: 1.8613 - val_accuracy: 0.4287
# Epoch 4/25
# 266/266 [==============================] - 176s 661ms/step - loss: 1.7206 - accuracy: 0.4798 - val_loss: 1.8799 - val_accuracy: 0.4407
# Epoch 5/25
# 266/266 [==============================] - 183s 689ms/step - loss: 1.5045 - accuracy: 0.5379 - val_loss: 2.4630 - val_accuracy: 0.3567
# Epoch 6/25
# 266/266 [==============================] - 172s 647ms/step - loss: 1.2695 - accuracy: 0.6086 - val_loss: 1.8019 - val_accuracy: 0.4660
# Epoch 7/25
# ...

# %% [markdown]
# ### **VGG Model**

# %%
def VGG_model(combination = 1):
    if combination == 1:
        optimizer = 'adam'
        loss = tf.keras.losses.sparse_categorical_crossentropy
    else:
        optimizer = 'sgd'
        loss = tf.keras.losses.sparse_categorical_crossentropy
    model = models.Sequential()
    model.add(layers.experimental.preprocessing.Resizing(224, 224, interpolation="bilinear", input_shape=x_train.shape[1:]))
    model.add(layers.Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
    model.add(tf.keras.layers.BatchNormalization(momentum=0.8))
    model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(units=4096,activation="relu"))
    model.add(layers.Dense(units=4096,activation="relu"))
    model.add(layers.Dense(classes_num, activation="softmax"))
    
    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])

    model.summary()
    return model

# %%
vgg1 = VGG_model(1)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# resizing_12 (Resizing)       (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_158 (Conv2D)          (None, 224, 224, 64)      1792
# _________________________________________________________________
# batch_normalization_156 (Bat (None, 224, 224, 64)      256
# _________________________________________________________________
# conv2d_159 (Conv2D)          (None, 224, 224, 64)      36928
# _________________________________________________________________
# batch_normalization_157 (Bat (None, 224, 224, 64)      256
# _________________________________________________________________
# max_pooling2d_62 (MaxPooling (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_160 (Conv2D)          (None, 112, 112, 128)     73856
# ...

# %%
# Adam optimizer, sparse categorical crossentropy loss
model_history5 = vgg1.fit(x_train, y_train, epochs=15, batch_size=64, validation_data=(x_val, y_val)) # 15 epochs
vgg1.save('vgg1.h5')
# Out:
# Epoch 1/15
# 133/133 [==============================] - 134s 996ms/step - loss: 8.6246 - accuracy: 0.1896 - val_loss: 2.7194 - val_accuracy: 0.2347
# Epoch 2/15
# 133/133 [==============================] - 131s 985ms/step - loss: 2.5668 - accuracy: 0.2713 - val_loss: 2.6955 - val_accuracy: 0.2933
# Epoch 3/15
# 133/133 [==============================] - 131s 984ms/step - loss: 2.4040 - accuracy: 0.2971 - val_loss: 2.2462 - val_accuracy: 0.3227
# Epoch 4/15
# 133/133 [==============================] - 131s 984ms/step - loss: 2.1869 - accuracy: 0.3464 - val_loss: 2.1816 - val_accuracy: 0.3607
# Epoch 5/15
# 133/133 [==============================] - 131s 984ms/step - loss: 2.0476 - accuracy: 0.3825 - val_loss: 2.1909 - val_accuracy: 0.3607
# Epoch 6/15
# 133/133 [==============================] - 131s 984ms/step - loss: 1.9276 - accuracy: 0.4121 - val_loss: 2.1942 - val_accuracy: 0.3673
# Epoch 7/15
# ...

# %%
vgg2 = VGG_model(2)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# resizing_2 (Resizing)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 224, 224, 64)      256
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 224, 224, 64)      36928
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 224, 224, 64)      256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 112, 112, 128)     73856
# ...

# %%
# Adam optimizer, categorical crossentropy loss
model_history6 = vgg2.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_val, y_val)) # 20 epochs
vgg2.save('vgg2.h5')
# Out:
# Epoch 1/20
# 133/133 [==============================] - 164s 1s/step - loss: 2.5871 - accuracy: 0.3039 - val_loss: 1.8940 - val_accuracy: 0.4400
# Epoch 2/20
# 133/133 [==============================] - 125s 940ms/step - loss: 1.6608 - accuracy: 0.4924 - val_loss: 1.8368 - val_accuracy: 0.4580
# Epoch 3/20
# 133/133 [==============================] - 125s 940ms/step - loss: 1.1453 - accuracy: 0.6541 - val_loss: 1.7216 - val_accuracy: 0.4993
# Epoch 4/20
# 133/133 [==============================] - 125s 940ms/step - loss: 0.6972 - accuracy: 0.7999 - val_loss: 1.5956 - val_accuracy: 0.5480
# Epoch 5/20
# 133/133 [==============================] - 125s 940ms/step - loss: 0.3531 - accuracy: 0.9184 - val_loss: 1.5261 - val_accuracy: 0.5647
# Epoch 6/20
# 133/133 [==============================] - 125s 940ms/step - loss: 0.1453 - accuracy: 0.9793 - val_loss: 1.4914 - val_accuracy: 0.5813
# Epoch 7/20
# ...

# %% [markdown]
# Σε αντίθεση με τα πρώτα δύο μοντέλα, παρατηρούμε ότι στην περίπτωση του μοντέλου VGG ο SGD optimizer φαίνεται να παρέχει καλύτερα ποσοστά ευστοχίας, γεγονός που οφείλεται στην εσωτερική αρχιτεκτονική πολλών επιπέδων του δικτύου.

# %% [markdown]
# ### **MyCNN Model**

# %% [markdown]
# Δημιουργούμε ένα δικό μας Συνελικτικό Νευρωνικό Δίκτυο, το οπόιο απότελείται από convolutional layers το μέγεθος των οποίων σταδιακά μειώνεται, ενώ ενδιάμεσα αυτών παρεμβάλλονται max-pooling layers  και μη γραμμικές συναρτήσεις ενεργοποίησης της μορφής **Leaky ReLU**, μέσω της οποίας δεν χρειάζεται να ανησυχούμε ιδιαίτερα για την αρχικοποίηση του δικτύου μας ή την κανονικοποίηση των δεδομένων εισόδου. Όπως θα φανεί, επιτυγχάνουμε το καλύτερο συγκριτικά με τα υπόλοιπα μοντέλα ποσοστό ευστοχίας.

# %%
def MyCNN(combination = 1):
    if combination == 1:
        optimizer = 'adam'
        loss = tf.keras.losses.sparse_categorical_crossentropy
    else:
        optimizer = 'adagrad'
        loss = tf.keras.losses.sparse_categorical_crossentropy

    model = models.Sequential()
    model.add(layers.Conv2D(128, (3,3), padding="same",input_shape=(32, 32, 3)))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Conv2D(128, (3, 3), padding='same'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Conv2D(256, (3, 3), padding='same'))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(512, (3, 3), padding='same'))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Conv2D(256, (3, 3)))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Flatten())
    model.add(layers.Dense(1024))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Dense(200))
    model.add(layers.Dense(classes_num, activation='softmax'))

    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    model.summary()
    return model

# %%
mycnn1 = MyCNN(1)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_37 (Conv2D)           (None, 32, 32, 128)       3584
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 16, 16, 256)       295168
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# ...

# %%
model_history7 = mycnn1.fit(x_train, y_train, epochs=10, batch_size=128, validation_data=(x_val, y_val)) # 10 epochs
mycnn1.save('mycnn1.h5')
# Out:
# Epoch 1/10
# 67/67 [==============================] - 7s 70ms/step - loss: 2.8606 - accuracy: 0.1256 - val_loss: 2.5989 - val_accuracy: 0.2213
# Epoch 2/10
# 67/67 [==============================] - 3s 49ms/step - loss: 2.3022 - accuracy: 0.2988 - val_loss: 2.0234 - val_accuracy: 0.3847
# Epoch 3/10
# 67/67 [==============================] - 3s 49ms/step - loss: 1.8085 - accuracy: 0.4444 - val_loss: 1.6345 - val_accuracy: 0.5173
# Epoch 4/10
# 67/67 [==============================] - 3s 49ms/step - loss: 1.4922 - accuracy: 0.5476 - val_loss: 1.4486 - val_accuracy: 0.5653
# Epoch 5/10
# 67/67 [==============================] - 3s 48ms/step - loss: 1.2293 - accuracy: 0.6220 - val_loss: 1.4130 - val_accuracy: 0.5973
# Epoch 6/10
# 67/67 [==============================] - 3s 48ms/step - loss: 0.9960 - accuracy: 0.6939 - val_loss: 1.3615 - val_accuracy: 0.6013
# Epoch 7/10
# ...

# %%
mycnn2 = MyCNN(2)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 32, 32, 128)       3584
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 16, 256)       295168
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# ...

# %%
model_history8 = mycnn2.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_val, y_val)) # 10 epochs
mycnn2.save('mycnn2.h5')
# Out:
# Epoch 1/10
# 133/133 [==============================] - 150s 1s/step - loss: 2.9917 - accuracy: 0.0582 - val_loss: 2.9707 - val_accuracy: 0.0967
# Epoch 2/10
# 133/133 [==============================] - 152s 1s/step - loss: 2.9632 - accuracy: 0.0987 - val_loss: 2.8853 - val_accuracy: 0.1393
# Epoch 3/10
# 133/133 [==============================] - 152s 1s/step - loss: 2.8410 - accuracy: 0.1474 - val_loss: 2.7800 - val_accuracy: 0.1627
# Epoch 4/10
# 133/133 [==============================] - 160s 1s/step - loss: 2.7063 - accuracy: 0.1865 - val_loss: 2.5204 - val_accuracy: 0.2340
# Epoch 5/10
# 133/133 [==============================] - 155s 1s/step - loss: 2.5559 - accuracy: 0.2298 - val_loss: 2.4523 - val_accuracy: 0.2287
# Epoch 6/10
# 133/133 [==============================] - 156s 1s/step - loss: 2.4318 - accuracy: 0.2744 - val_loss: 2.3074 - val_accuracy: 0.2967
# Epoch 7/10
# ...

# %% [markdown]
# #### **Βήμα 2: Αξιολόγηση των μοντέλων**
#
# 1. Για κάθε ένα από τα μοντέλα που εκπαιδεύσατε, απεικονίστε σε κοινό διάγραμμα την ορθότητα εκπαίδευσης και την ορθότητα επικύρωσης στο σύνολο των εποχών, για κάθε διαφορετικό συνδυασμό του βήματος 1 και επιλέξτε αυτό με την καλύτερη ορθότητα από κάθε μοντέλο (ένα από κάθε αρχιτεκτονική, συνολικά 4).
# 2. Για κάθε ένα από τα μοντέλα με την καλύτερη ορθότητα (συνολικά **4**), απεικονίστε σε κοινό διάγραμμα την ορθότητα εκπαίδευσης και την ορθότητα επικύρωσης στο σύνολο των εποχών.
# 3. Αξιολογήστε, αναλυτικά, τα αποτελέσματά σας ως προς τα εξής:
#  - Επίδραση του πλήθους των δεδομένων/κλάσεων στην απόδοση του μοντέλου
#  - Επίδραση του αλγόριθμου βελτιστοποίησης (optimizer)
#  - Επίδραση του μεγέθους δέσμης (batch size)
#
#
# ---

# %% [markdown]
# ### **LeNet Model**

# %%
# LeNet Model - 1st combination
plot_accuracy(model_history1)
plt.show()

# %%
# LeNet Model - 2nd combination
plot_accuracy(model_history2)
plt.show()

# %% [markdown]
# Παρατηρούμε, λοιπόν, ότι ο πρώτος συνδυασμός υπερπαραμέτρων για το Lenet δίνει καλύτερο αποτελέσματα ευστοχίας, ενώ ο δεύτερος συνδυασμός αποτυγχάνει παταγωδώς, καθώς χρησιμοποιείται η sigmoid με μεθόδους gradient descent.

# %% [markdown]
# ### **AlexNet Model**

# %%
# AlexNet Model - 1st combination
plot_accuracy(model_history3)
plt.show()

# %%
# AlexNet Model - 2nd combination
plot_accuracy(model_history4)
plt.show()

# %% [markdown]
# Ομοίως με το πρώτο μοντέλο, ο Adam optimizer υπερτερεί του SGD, ο οποίος φαίνεται να οδηγεί το μοντέλο πιο γρήγορο προς φαινόμενα υπερεκπαίδευσης (**overfitting**).

# %% [markdown]
# ### **VGG Model**

# %%
# VGG Model - 1st combination
plot_accuracy(model_history5)
plt.show()

# %%
# VGG Model - 2nd combination
plot_accuracy(model_history6)
plt.show()

# %% [markdown]
# Όπως τονίστηκε, σε αντίθεση με τα δύο πρώτα μοντέλα, ο δεύτερος συνδυασμός με τον SGD optimizer φαίνεται να δίνει καλύτερα ποσοστά ευστοχίας.

# %% [markdown]
# ### **MyCNN Model**

# %%
# MyCNN Model - 1st combination
plot_accuracy(model_history7)
plt.show()

# %%
# MyCNN Model - 2nd combination
plot_accuracy(model_history8)
plt.show()

# %% [markdown]
# Παρατηρούμε, λοιπόν, ότι ο πρώτος συνδυασμός υπερπαραμέτρων για το MyCNN δίνει καλύτερο αποτελέσματα ευστοχίας.

# %% [markdown]
# #### **Ευστοχία Μοντέλων σε Κοινό Διάγραμμα**
# Στη συνέχεια, σχεδιάζουμε σε κοινό διάγραμμα τις καμπύλες ευστοχίας για όλα τα μοντέλα που εκπαιδεύσαμε ανά εποχή - τόσο για το train dataset όσο και για το validation set. Για κάθε μοντέλο, κρατάμε την παραμετροποίηση εκείνη που έδωσε τα καλύτερα ποσοστά ευστοχίας. Με τον τρόπο αυτό, φαίνεται ξεκάθαρα η υπεροχή του δικού μας CNN λόγω των πολλών συνελικτικών επιπέδων με τα οποία είναι εφοδιασμένο.

# %%
def plot_all(histories, labels):
    fig = plt.figure(figsize=(9,9))
    plt.title("Train and Validation Accuracy of Neural Network Models")
    i=0
    colors = ['b','r','g','m','y']
    for history in histories:
        plt.plot(history.history['accuracy'], label=labels[i]+': accuracy', color=colors[i%5])
        plt.plot(history.history['val_accuracy'], linestyle='dashed', label = labels[i] + ': val_accuracy',color=colors[i%5])
        i+=1

    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

plot_all([model_history1, model_history3, model_history6, model_history7], ['LeNet','AlexNet','VGG','MyCNN'])

# %% [markdown]
# - **Επίδραση του πλήθους των δεδομένων/κλάσεων στην απόδοση του μοντέλου:**<br>
# Παρατηρούμε ότι αυξάνοντας το πλήθος των εικόνων εισόδου της βάσης CIFAR100 για την εκπαίδευση του CNN, η απόδοση του δικτύου μειώνεται ενώ αυξάνεται ο χρόνος που απαιτείται για την ολοκλήρωση κάθε εποχής. Αυτό συμβαίνει διότι, εισάγοντας περισσότερες εικόνες δημιουργούνται επιπλέον κλάσεις και άρα το πρόβλημα του image classification γίνεται πιο σύνθετο (επιτάσσει τη χρήση μεγαλύτερων training sets), επιφέροντας μικρότερη ευστοχία. Επιπλέον, η φόρτωση επιπλέον εικόνων επιβαρύνει αισθητά τη μνήμη του συστήματος και άρα την ταχύτητα εκπαίδευσης του δικτύου, γι'αυτό και όπως θα φανεί στη συνέχεια προτιμάται η χρήση κάποιας μεθόδου data augmentation.
#
# - **Επίδραση του αλγόριθμου βελτιστοποίησης (optimizer):**<br>
# Παρατηρούμε ότι ο Adam optimizer επιτυγχάνει πιο γρήγορη σύγκλιση σε σύγκριση με τον SGD Optimizer, ο οποίος απαιτεί τη διέλευση πολλών εποχών για την επίτευξη ικανοποιητικών ποσοστών ευστοχίας. Επιπλέον, με εξαίρεση το VGG δίκτυο, o Adam optimizer επιφέρει καλύτερα ποσοστά ευστοχίας από τον SGD, ο οποίος πιο έυκολα εγκλωβίζεται σε τοπικά ελάχιστα της συνάρτησης κόστους ή υποπίπτει σε φαινόμενα overfitting. Επιπλέον, πειραματιζόμενοι και με τον Adagrad optimizer βλέπουμε ότι επιτυγχάνει μεγαλύτερη ευρωστία από τον SGD.
#
#
# - **Επίδραση του μεγέθους δέσμης (batch size):**<br>
# Αυξάνοντας το  batch size παρατηρούμε ότι, όπως είναι φυσικό, η εκπαίδευση του νευρωνικού ανά εποχή τερματίζει πιο γρήγορα, ωστόσο η συνολική σύγκλιση σε ικανοποιητικά ποσοστά ευστοχίας επιβραδύνεται. Γενικότερα μεγαλύτερο batch size επιτυγχάνει μικρότερο variance στο μοντέλο αφού κάθε φορά η ενημέρωση γίνεται βάσει πολλών εικόνων εισόδου. Από την άλλη, επιλέγοντας μικρότερο batch size σε συνδυασμό με τεχνικές μάθησης gradient descent, μπορούμε να προσδώσουμε επιπλέον θόρυβο στην εκπαίδευση του μοντέλου, ώστε αυτό να απεγκλωβίζεται με ευκολία από τοπικά ελάχιστα της συνάρτησης κριτηρίου. Στην πράξη, βέβαια, αποφεύγουμε να διαλέξουμε πάρα πολύ μικρό batch size, καθώς τα ποσοστά ευστοχίας δεν θα φτάσουν σε ένα ικανοποιητικό επίπεδο.
#
# - **Επίδραση της συνάρτησης κόστους (loss function):**<br>
# Αν και δεν ζητείται, σημειώνεται ότι κατά κύριο λόγο η συνάρτηση κόστους που χρησιμοποιείται είναι η sparse categorical crossentropy, καθώς πρόκειται για ένα multiclass image classification πρόβλημα. Οποιαδήποτε άλλη συνάρτηση κόστους επιλέχθηκε, επιτυγχάνει πολύ άσχημα ποσοστά ευστοχίας, γι'αυτό και εν τέλει αποφεύγουμε τη χρήση τους.

# %% [markdown]
# #### **Βήμα 3: Αξιολόγηση ορθότητας**
#
# Αξιολογήστε την ορθότητα για το test set σας.

# %% [markdown]
# ### **LeNet Model**

# %%
print("====== LeNet Model - 1st Combination ======")
model_evaluation(LeNet1, 20)
print("\n====== LeNet Model - 2nd Combination ======")
model_evaluation(LeNet2, 20)
# Out:
# ====== LeNet Model - 1st Combination ======
#
# Test set Evaluation metrics
# 20/20 [==============================] - 0s 3ms/step - loss: 2.0532 - accuracy: 0.3795
# Loss: 2.05
# Accuracy: 0.38
#
# ====== LeNet Model - 2nd Combination ======
#
# Test set Evaluation metrics
# 20/20 [==============================] - 0s 3ms/step - loss: 2.9959 - accuracy: 0.0500
# Loss: 3.00
# Accuracy: 0.05

# %% [markdown]
# ### **AlexNet Model**

# %%
print("====== AlexNet Model - 1st Combination ======")
model_evaluation(AlexNet1, 20)
print("\n====== AlexNet Model - 2nd Combination ======")
model_evaluation(AlexNet2, 20)
# Out:
# ====== AlexNet Model - 1st Combination ======
#
# Test set Evaluation metrics
# 20/20 [==============================] - 8s 385ms/step - loss: 1.5336 - accuracy: 0.6075
# Loss: 1.53
# Accuracy: 0.61
#
# ====== AlexNet Model - 2nd Combination ======
#
# Test set Evaluation metrics
# 20/20 [==============================] - 8s 385ms/step - loss: 2.1300 - accuracy: 0.6050
# Loss: 2.13
# Accuracy: 0.61

# %% [markdown]
# ### **VGG Model**

# %%
print("====== VGG Model - 1st Combination ======")
model_evaluation(vgg1, 20)
print("\n====== VGG Model - 2nd Combination ======")
model_evaluation(vgg2, 20)
# Out:
# ====== VGG Model - 1st Combination ======
#
# Test set Evaluation metrics
# 20/20 [==============================] - 26s 475ms/step - loss: 2.8413 - accuracy: 0.4180
# Loss: 2.84
# Accuracy: 0.42
#
# ====== VGG Model - 2nd Combination ======
#
# Test set Evaluation metrics
# 20/20 [==============================] - 10s 459ms/step - loss: 1.6141 - accuracy: 0.6050
# Loss: 1.61
# Accuracy: 0.61

# %% [markdown]
# ### **MyCNN Model**

# %%
print("====== MyCNN Model - 1st Combination ======")
model_evaluation(mycnn1, 20)
print("\n====== MyCNN Model - 2nd Combination ======")
model_evaluation(mycnn2, 20)
# Out:
# ====== MyCNN Model - 1st Combination ======
#
# Test set Evaluation metrics
# 20/20 [==============================] - 6s 289ms/step - loss: 1.7608 - accuracy: 0.6285
# Loss: 1.76
# Accuracy: 0.63
#
# ====== MyCNN Model - 2nd Combination ======
#
# Test set Evaluation metrics
# 20/20 [==============================] - 6s 292ms/step - loss: 2.1397 - accuracy: 0.3565
# Loss: 2.14
# Accuracy: 0.36

# %% [markdown]
# ## Ερώτημα 2
# ---
# ### Βήμα 1: Έλεγχος υπερεκπαίδευσης
#
# Για τον καλύτερο συνδυασμό που λάβατε από το Ερώτημα 1 για μοντέλο σας  (**MyCNN**) και μόνο, δοκιμάστε διάφορους συνδυασμούς των ακόλουθων τεχνικών για τον έλεγχο της υπερεκπαίδευσης (overfitting), όπως:
# - Πρόωρος τερματισμός (early stopping [tf.keras.callbacks.EarlyStopping](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStoppinghttps://))
#
# - Dropout ([Dropout](https://www.tensorflow.org/tutorials/images/classification#dropout))
#
# - Επαύξηση δεδομένων ([Data augmentation](https://www.tensorflow.org/tutorials/images/classification#data_augmentation), [ImageDataGenerator](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator#class_imagedatagenerator))
#
# \
# , ώστε το μοντέλο σας να γενικεύει καλύτερα.

# %% [markdown]
# ### Dropout
# ---
#
# Μέσω της τεχνικής του dropout επιλέγουμε να αγνοήσουμε τυχαιοκρατικά συγκεκριμένες δομικές μονάδες του Νευρωνικού δικτύου, κατά τη διάρκεια της εκπαίδευσης του, επιβάλλοντας σε αυτές μηδενικά βάρη. Με αυτόν τον τρόπο, η κατανομή των τιμών που λαμβάνουν τα βάρη του νευρωνικού προσεγξίζουν την **Κανονική Κατανομή** (gaussian), και εν τέλει περιορίζεται σε μεγάλο βαθμό το φαινόμενο του overfitting. Δημιουργούμε, λοιπόν, εκ νέου το μοντέλο MyCNN που έδωσε τα καλύτερα αποτελέσματα, εφοδιασμένο με τεχνικές dropout.
#
# ---

# %%
def MyCNN_dropout(combination = 1):
    if combination == 1:
        optimizer = 'adam'
        loss = tf.keras.losses.sparse_categorical_crossentropy
    else:
        optimizer = 'adam'
        loss = tf.keras.losses.categorical_crossentropy

    model = models.Sequential()
    model.add(layers.Conv2D(128, (3,3), padding="same",input_shape=(32, 32, 3)))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Conv2D(128, (3, 3), padding='same'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.05))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Conv2D(256, (3, 3), padding='same'))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.05))
    model.add(layers.Conv2D(512, (3, 3), padding='same'))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Conv2D(256, (3, 3)))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.05))
    model.add(layers.Flatten())
    model.add(layers.Dense(1024))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Dropout(0.05))
    model.add(layers.Dense(200))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Dropout(0.05))
    model.add(layers.Dense(classes_num, activation='softmax'))
    model.add(layers.Dropout(0.05))


    model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
    model.summary()
    return model

# %%
mycnn3 = MyCNN_dropout(combination = 1)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_35 (Conv2D)           (None, 32, 32, 128)       3584
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 16, 16, 256)       295168
# ...

# %% [markdown]
# ### Early Stopping
# ---
#
# Μέσω της τεχνικής του Early Stopping, η εκπαίδευση του Νευρωνικού δικτύου τερματίζεται όταν η απόδοση του παύει να βελτιώνεται μετά τη διέλευση κάποιων εποχών. Με τον τρόπο αυτό, αποτρέπεται η εμφάνιση φαινομένων overfitting, ωστόσο το σφάλμα γενίκευσης τείνει να αυξηθεί. Σε πρώτο στάδιο, δοκιμάζουμε να εκπαιδεύσουμε το εφοδιασμένο με dropouts MyCNN με χρήση τεχνικών Early Stopping, και ειδικότερα τερματίζουμε τη διαδικασία έπειτα από **3 διαδοχικές μειώσεις της απόδοσης**.
#
# ---

# %%
# Apply early stopping after 3 consecutive epochs with decreasing performance  
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)


model_history9 = mycnn3.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_val, y_val)
                           ,callbacks = callback) # 50 epochs

mycnn3.save('mycnn3_earlystop.h5')
# Out:
# Epoch 1/50
# 67/67 [==============================] - 161s 2s/step - loss: 3.5918 - accuracy: 0.0864 - val_loss: 2.4602 - val_accuracy: 0.2427
# Epoch 2/50
# 67/67 [==============================] - 174s 3s/step - loss: 2.8909 - accuracy: 0.2831 - val_loss: 1.9304 - val_accuracy: 0.4167
# Epoch 3/50
# 67/67 [==============================] - 175s 3s/step - loss: 2.5094 - accuracy: 0.4428 - val_loss: 1.7682 - val_accuracy: 0.4880
# Epoch 4/50
# 67/67 [==============================] - 164s 2s/step - loss: 2.0773 - accuracy: 0.5252 - val_loss: 1.4167 - val_accuracy: 0.5780
# Epoch 5/50
# 67/67 [==============================] - 164s 2s/step - loss: 1.8853 - accuracy: 0.5985 - val_loss: 1.3580 - val_accuracy: 0.6200
# Epoch 6/50
# 67/67 [==============================] - 164s 2s/step - loss: 1.6276 - accuracy: 0.6625 - val_loss: 1.4814 - val_accuracy: 0.5993
# Epoch 7/50
# ...

# %% [markdown]
# ### Data Augmentation
# ---
#
# Μέσω της τεχνικής του Data Augmentation, αντιμετωπίζουμε το πρόβλημα ανεπάρκειας δεδομένων εκπαίδευσης - και κατεπέκταση το overfitting - καθώς δημιουργούνται νέα δεδομένα, εφαρμόζωντας τυχαίους μετασχηματισμούς στα ήδη υπαρκτά. Σημειώνεται επίσης ότι τα νέα 'επαυξημένα' δεδομένα κατατάσσονται στην ίδια κλάση με αυτά από τα οποία προήλθαν.
#
# ---

# %%
from keras.utils import to_categorical

# %%
# Apply data augmentation
y_train_aug = to_categorical(y_train, classes_num)
y_test_aug = to_categorical(y_test, classes_num)
y_val_aug = to_categorical(y_val, classes_num)

# Data generator for train and validation set
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.2)

# Data generator for test set
test_data_generator = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# compute quantities required for featurewise normalization (std, mean, and principal components)
data_generator.fit(x_train)

# %% [markdown]
# Στη συνέχεια, εκπαιδεύουμε εκ νέου το μοντέλο μας πάνω στα επαυξημένα δεδομένα, συνδυάζοντας και τις τεχνικές Dropout και Early Stopping.

# %%
mycnn4 = MyCNN_dropout(combination = 2) # categorical crossentropy loss
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_10 (Conv2D)           (None, 32, 32, 128)       3584
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 256)       295168
# ...

# %%
# Apply early stopping after 3 consecutive epochs with decreasing performance  
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

model_history10 = mycnn4.fit(data_generator.flow(x_train, y_train_aug, batch_size=128),
                    steps_per_epoch=len(x_train)/128, epochs=50,
                    validation_data=data_generator.flow(x_val, y_val_aug, batch_size=128),
                    validation_steps = len(x_val)/128, callbacks=callback) # 50 epochs

mycnn4.save('mycnn4_final.h5')
# Out:
# Epoch 1/50
# 66/66 [==============================] - 151s 2s/step - loss: 3.4302 - accuracy: 0.1527 - val_loss: 2.2675 - val_accuracy: 0.2993
# Epoch 2/50
# 66/66 [==============================] - 153s 2s/step - loss: 2.8819 - accuracy: 0.3266 - val_loss: 1.9078 - val_accuracy: 0.4167
# Epoch 3/50
# 66/66 [==============================] - 156s 2s/step - loss: 2.6635 - accuracy: 0.4160 - val_loss: 1.7499 - val_accuracy: 0.4693
# Epoch 4/50
# 66/66 [==============================] - 155s 2s/step - loss: 2.3649 - accuracy: 0.4730 - val_loss: 1.5689 - val_accuracy: 0.5267
# Epoch 5/50
# 66/66 [==============================] - 150s 2s/step - loss: 2.1886 - accuracy: 0.5337 - val_loss: 1.5049 - val_accuracy: 0.5467
# Epoch 6/50
# 66/66 [==============================] - 159s 2s/step - loss: 2.0197 - accuracy: 0.5629 - val_loss: 1.4449 - val_accuracy: 0.5680
# Epoch 7/50
# ...

# %% [markdown]
# ---
# ### Βήμα 2: Αξιολόγηση
# Αξιολογήστε της ορθότητας για το validation και το test set σας.

# %%
# MyCNN Model - Dropout & Early Stopping
plot_accuracy(model_history9)
plt.show()

# %%
# MyCNN Model - Dropout & Early Stopping & Data Augmentation
plot_accuracy(model_history10)
plt.show()

# %%
print("====== MyCNN Model - Dropout, Early Stopping ======")

print('Validation set Evaluation metrics')
loss, accuracy = mycnn3.evaluate(x_val, y_val)
print("Loss: {:.2f}".format(loss))
print("Accuracy: {:.2f}".format(accuracy))

print('\nTest set Evaluation metrics')
loss, accuracy = mycnn3.evaluate(x_test, y_test)
print("Loss: {:.2f}".format(loss))
print("Accuracy: {:.2f}".format(accuracy))
# Out:
# ====== MyCNN Model - Dropout, Early Stopping ======
# Validation set Evaluation metrics
# 47/47 [==============================] - 6s 132ms/step - loss: 4.3855 - accuracy: 0.5993
# Loss: 4.39
# Accuracy: 0.60
#
# Test set Evaluation metrics
# 63/63 [==============================] - 9s 136ms/step - loss: 4.4858 - accuracy: 0.5965
# Loss: 4.49
# Accuracy: 0.60

# %%
print("\n====== MyCNN Model - Dropout, Early Stopping, Data Augmentation ======")

print('Validation set Evaluation metrics')
loss, accuracy = mycnn4.evaluate(data_generator.flow(x_val, y_val_aug, batch_size=128))
print("Loss: {:.2f}".format(loss))
print("Accuracy: {:.2f}".format(accuracy))

print('\nTest set Evaluation metrics')
loss, accuracy = mycnn4.evaluate(data_generator.flow(x_test, y_test_aug, batch_size=128))
print("Loss: {:.2f}".format(loss))
print("Accuracy: {:.2f}".format(accuracy))
# Out:
# ====== MyCNN Model - Dropout, Early Stopping, Data Augmentation ======
# Validation set Evaluation metrics
# 12/12 [==============================] - 6s 526ms/step - loss: 1.1624 - accuracy: 0.6727
# Loss: 1.16
# Accuracy: 0.67
#
# Test set Evaluation metrics
# 16/16 [==============================] - 9s 535ms/step - loss: 1.1244 - accuracy: 0.6895
# Loss: 1.12
# Accuracy: 0.69

# %% [markdown]
# ## Ερώτημα 3
# ---
# ### Βήμα 1: Μεταφορά γνώσης
# Εφαρμόστε μεταφορά γνώσης (transfer learning) στο δικό σας μοντέλο (**MyCNN**), που αξιολογήσατε ως καλύτερο προς την ακρίβεια στην αντιμετώπιση της υπερεκπαίδεσης.
#
# Για το transfer learning επιλέξτε το [VGG16](https://www.tensorflow.org/api_docs/python/tf/keras/applications/vgg16) για μεταφορά μάθησης.
#
# 1. "Παγώστε" τη συνελικτική βάση και εκπαιδεύστε την κεφαλή ταξινόμησης (classification head - σημαία trainable = False).
#
# 2. Εκπαιδέστε μόνο ένα ποσοστό των επιπέδων, το οποίο βρίσκεται προς την έξοδο του δικτύου. Οι σημαίες trainable εδώ θα πρέπει να οριστούν ανά επίπεδο.
#
# 3. Αξιολογήστε τα αποτελέσματά σας, βάσει της ορθότητας του validation set και του test set σας.
#
# ---

# %% [markdown]
# Σε πρώτο στάδιο, φορτώνουμε την κεφαλή του προεκπαιδευμένου νευρωνικού Δικτύου και παγώνουμε τα βάρη της. Ενσωματώνουμε την κεφαλή του MyCNN και εκπαιδεύουμε μόνο τα βάρη αυτής.

# %%
# Transfel Learning 1: Load Pretrained Model and Freeze Convolutional Base
pretrained_model = tf.keras.applications.VGG16(
    include_top=False, weights='imagenet', input_tensor=None, input_shape=(32,32,3),
    pooling=max, classes=classes_num
)
pretrained_model.trainable=False # Freeze Weights

# %%
# Combine Pretrained Model with MyCNN
def transfer_model():
    
    model = models.Sequential([pretrained_model])
    model.add(layers.Flatten()),
    model.add(layers.Dense(1024)),
    model.add(tf.keras.layers.LeakyReLU()),
    model.add(layers.Dropout(0.15)),
    model.add(layers.Dense(200))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Dropout(0.18))
    model.add(layers.Dense(classes_num, activation='softmax'))
    model.add(layers.Dropout(0.2))
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# %%
transfer_model1 = transfer_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 1024)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               205000
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 200)               0
# ...

# %%
# Train Model
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

model_history11 = transfer_model1.fit(data_generator.flow(x_train, y_train_aug, batch_size=128),
                    steps_per_epoch=len(x_train)/128, epochs=25,
                    validation_data=data_generator.flow(x_val, y_val_aug, batch_size=128),
                    validation_steps = len(x_val)/128, callbacks=callback) # 25 epochs

transfer_model1.save('transfer1.h5')
# Out:
# Epoch 1/25
# 66/66 [==============================] - 41s 611ms/step - loss: 4.8401 - accuracy: 0.2932 - val_loss: 1.5266 - val_accuracy: 0.5380
# Epoch 2/25
# 66/66 [==============================] - 47s 708ms/step - loss: 4.3984 - accuracy: 0.4651 - val_loss: 1.4370 - val_accuracy: 0.5587
# Epoch 3/25
# 66/66 [==============================] - 44s 657ms/step - loss: 4.0598 - accuracy: 0.4885 - val_loss: 1.3993 - val_accuracy: 0.5627
# Epoch 4/25
# 66/66 [==============================] - 47s 712ms/step - loss: 4.2497 - accuracy: 0.4988 - val_loss: 1.4103 - val_accuracy: 0.5787
# Epoch 5/25
# 66/66 [==============================] - 52s 785ms/step - loss: 3.9716 - accuracy: 0.5192 - val_loss: 1.3202 - val_accuracy: 0.5800
# Epoch 6/25
# 66/66 [==============================] - 45s 674ms/step - loss: 4.0746 - accuracy: 0.5331 - val_loss: 1.3756 - val_accuracy: 0.5833
# Epoch 7/25
# ...

# %% [markdown]
# Στη συνέχεια, δοκιμάζουμε να εκπαιδεύσουμε μόνο ένα ποσοστό επιπέδων του νευρωνικού δικτύου που βρίσκονται κοντά στην έξοδο του. Πιο συγκεκριμένα, φορτώνουμε προεκπαιδευμένα βάρη για το τρίτο από το τέλος Dense Layer του Νευρωνικού και φριζάρουμε την εκπαίδευση του, επιτρέποντας την εκπάιδευση μόνο των δύο κοντινότερων προς την έξοδο layers.

# %%
# Transfer Learning 2: Train only a partion of outer layers
def transfer_model2():
    
    model = models.Sequential([pretrained_model])
    model.add(layers.Flatten()),
    model.add(layers.Dense(1024, trainable=False)),
    model.add(tf.keras.layers.LeakyReLU()),
    model.add(layers.Dropout(0.15)),
    model.add(layers.Dense(200))
    model.add(tf.keras.layers.LeakyReLU())
    model.add(layers.Dropout(0.18))
    model.add(layers.Dense(classes_num, activation='softmax'))
    model.add(layers.Dropout(0.2))
    
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.summary()
    return model

# %%
transfer_model2 = transfer_model2()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# vgg16 (Functional)           (None, 1, 1, 512)         14714688
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 200)               205000
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 200)               0
# ...

# %%
# Set third to last Dense Layer wights fromm pretrained model
weights = transfer_model1.layers[-8].get_weights()  
transfer_model2.layers[-8].set_weights(weights)

# %%
# Train only last two dense layers
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

model_history12 = transfer_model2.fit(data_generator.flow(x_train, y_train_aug, batch_size=128),
                    steps_per_epoch=len(x_train)/128, epochs=25,
                    validation_data=data_generator.flow(x_val, y_val_aug, batch_size=128),
                    validation_steps = len(x_val)/128, callbacks=callback) # 25 epochs

transfer_model2.save('transfer2.h5')
# Out:
# Epoch 1/25
# 66/66 [==============================] - 45s 677ms/step - loss: 4.7187 - accuracy: 0.3439 - val_loss: 1.3590 - val_accuracy: 0.5820
# Epoch 2/25
# 66/66 [==============================] - 42s 640ms/step - loss: 3.9757 - accuracy: 0.5349 - val_loss: 1.3830 - val_accuracy: 0.5853
# Epoch 3/25
# 66/66 [==============================] - 40s 602ms/step - loss: 4.0248 - accuracy: 0.5453 - val_loss: 1.3108 - val_accuracy: 0.6093
# Epoch 4/25
# 66/66 [==============================] - 39s 588ms/step - loss: 3.9583 - accuracy: 0.5613 - val_loss: 1.3218 - val_accuracy: 0.6047
# Epoch 5/25
# 66/66 [==============================] - 40s 599ms/step - loss: 4.0341 - accuracy: 0.5689 - val_loss: 1.3358 - val_accuracy: 0.5907
# Epoch 6/25
# 66/66 [==============================] - 42s 629ms/step - loss: 3.9378 - accuracy: 0.5695 - val_loss: 1.3122 - val_accuracy: 0.6060
# Epoch 7/25
# ...

# %% [markdown]
# Τέλος, αξιολογούμε τα δύο άνωθι μοντέλα ως προς την ορθότητα τους στο validation και test set.

# %%
# Transfer Learning - Freeze Weights of VGG16
plot_accuracy(model_history11)
plt.show()

# %%
# Transfer Learning - Freeze Weights of VGG16 and Third to Last Dense Layer
plot_accuracy(model_history12)
plt.show()

# %%
print("\n====== Transfer Learning - First Model ======")

print('Validation set Evaluation metrics')
loss, accuracy = transfer_model1.evaluate(data_generator.flow(x_val, y_val_aug, batch_size=128))
print("Loss: {:.2f}".format(loss))
print("Accuracy: {:.2f}".format(accuracy))

print('\nTest set Evaluation metrics')
loss, accuracy = transfer_model1.evaluate(data_generator.flow(x_test, y_test_aug, batch_size=128))
print("Loss: {:.2f}".format(loss))
print("Accuracy: {:.2f}".format(accuracy))
# Out:
# ====== Transfer Learning - First Model ======
# Validation set Evaluation metrics
# 12/12 [==============================] - 7s 604ms/step - loss: 1.3429 - accuracy: 0.6067
# Loss: 1.34
# Accuracy: 0.61
#
# Test set Evaluation metrics
# 16/16 [==============================] - 9s 555ms/step - loss: 1.3555 - accuracy: 0.5970
# Loss: 1.36
# Accuracy: 0.60

# %%
print("\n====== Transfer Learning - Second Model ======")

print('Validation set Evaluation metrics')
loss, accuracy = transfer_model2.evaluate(data_generator.flow(x_val, y_val_aug, batch_size=128))
print("Loss: {:.2f}".format(loss))
print("Accuracy: {:.2f}".format(accuracy))

print('\nTest set Evaluation metrics')
loss, accuracy = transfer_model2.evaluate(data_generator.flow(x_test, y_test_aug, batch_size=128))
print("Loss: {:.2f}".format(loss))
print("Accuracy: {:.2f}".format(accuracy))
# Out:
# ====== Transfer Learning - Second Model ======
# Validation set Evaluation metrics
# 12/12 [==============================] - 7s 565ms/step - loss: 1.3151 - accuracy: 0.6300
# Loss: 1.32
# Accuracy: 0.63
#
# Test set Evaluation metrics
# 16/16 [==============================] - 9s 574ms/step - loss: 1.3927 - accuracy: 0.6050
# Loss: 1.39
# Accuracy: 0.61

# %% [markdown]
# Όπως είναι λογικό, η χρήση προεκπαιδευμένων μοντέλων επιταχύνει τη διαδικασία σύγκλισης και εκπαίδευσης του νευρωνικού δικτύου, δίχως να επιβαρύνεται το τελικό ποσοστό ευστοχίας. Επιπλέον, επιλέγοντας να 'παγώσουμε' τα βάρη ενός τμήματος επιπέδων που βρίσκονται κοντά στην έξοδο του δικτύου, επιτυγχάνουμε λίγο καλύτερα ποσοστά ευστοχίας και φυσικά επιταχύνουμε ακόμα περισσότερο την εκπαίδευση του δικτύου. Στην πράξη, αξιοποιούμε τη συνελικτική βάση μοντέλων που έχουν αποδεδειγμένα υψηλά ποσοστά ευστοχίας σε προβλήματα image classification και τροποιούμε μόνο την κεφαλή του δικτύου με βάση το εκάσοτε πρόβλημα, γλυτώνοντας έτσι χρόνο και κόπο.
